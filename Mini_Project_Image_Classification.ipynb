# %% [markdown]
# <a href="https://colab.research.google.com/github/graveshacks/Mini-Project---Image-Classification/blob/main/Mini_Project_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python --quiet

# %%
#Preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from PIL import Image
import cv2
import pickle

# %%
#display image
img = imread("/content/drive/MyDrive/Cats and Dogs/cats/cat.4001.jpg")
plt.imshow(img)

# %%
img.shape
# Out:
# (415, 498, 3)

# %%
import os
import numpy as np
datadir = '/content/drive/MyDrive/Cats and Dogs'

categories = ['cats','dogs'] # Name the folder with these categories
data = []

for i in categories:
  path = os.path.join(datadir,i)
  label = categories.index(i)
  #print(path)
  for img in os.listdir(path):
    img_array = os.path.join(path,img)
    pets_img = cv2.imread(img_array,0)
    try:
      pets_img = cv2.resize(pet_img, (50,50))
      image = np.array(pet_img).flatten()

      data.append([image, label])
    except Exception as e:
      pass

pick_in = open('data1.pickle','wb')
pickle.dump(data,pick_in)
pick_in.close()

# %%
pick_in = open('data1.pickle','rb')
pickle.load(pick_in)
data = pick_in.close()

# %%
features = []
labels = []

for feature, label in data:
  features.append(feature)
  labels.append(label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-135a5ec23ff4> in <module>()
#       2 labels = []
#       3
# ----> 4 for feature, label in data:
#       5   features.append(feature)
#       6   labels.append(label)
#
# TypeError: 'NoneType' object is not iterable

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain,ytest = train_test_split(features, labels, test_size=0.05, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-696d8ca713ff> in <module>()
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 xtrain,xtest,ytrain,ytest = train_test_split(features, labels, test_size=0.05, random_state=0)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2120     n_samples = _num_samples(arrays[0])
#    2121     n_train, n_test = _validate_shuffle_split(n_samples, test_size, train_size,
# -> 2122                                               default_test_size=0.25)
#    2123
#    2124     if shuffle is False:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    1803             'resulting train set will be empty. Adjust any of the '
# ...

# %%
from sklearn.svm import SVC

model = SVC(C=1, kernel='poly',gamma='auto')
model.fit(xtrain, ytrain)

pred = model.predict(xtest)
accuracy = model.score(xtest, ytest)

categories = ['cats','dogs']
print("Accuracy: ", accuracy)
print("Prediction is: ", categories[pred[0]])

mypet = xtest[0].reshape[50,50]
plt.imshow(mypet, cmap='gray')
plt.show()

# %%
pick = open('medel.sav', 'wb')
pickle.dump(model, pick)
pick.close()

# %%
pick = open('medel.sav', 'rb')
model = pickle.load(pick)
pick.close()
